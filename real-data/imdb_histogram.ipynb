# %%
import torch
import matplotlib.pyplot as plt

# %% [markdown]
# # Tools

# %%
def get_k_parameters(model):
    parameter = []
    for block in model.blocks:
        parameter.append(
            block.attn.attn_matrix.weight.data.abs()[384:768, :]
        )
    return torch.cat(parameter)

# %%
def get_q_parameters(model):
    parameter = []
    for block in model.blocks:
        parameter.append(
            block.attn.attn_matrix.weight.data.abs()[:384, :]
        )
    return torch.cat(parameter)

# %%
def get_v_parameters(model):
    parameter = []
    for block in model.blocks:
        parameter.append(
            block.attn.attn_matrix.weight.data.abs()[768:, :]
        )
    return torch.cat(parameter)

# %% [markdown]
# # Plots

# %%
# refer to the following for font size help
# https://stackoverflow.com/questions/3899980/how-to-change-the-font-size-on-a-matplotlib-plot
plt.rcParams.update({'font.size': 22})

# %%
result = torch.load("results/1.1/6/1.pt", map_location=torch.device('cpu'))
model = result["model"]
parameter = get_k_parameters(model).flatten()
print((parameter > 0.06).sum())
hist = torch.histogram(parameter[parameter > 0.06], bins=torch.tensor([0.0 + 0.005 * idx for idx in range(200)]))
plt.stairs(hist.hist.detach().numpy(), hist.bin_edges.detach().numpy(), fill=True)
plt.plot(parameter.max(), 60,'ro') 
plt.xlim([0.06, 1.03])
plt.ylim([0, 5_000])
plt.xlabel("Parameter Magnitude")
plt.ylabel("Frequency")
plt.savefig("Parameter_K_1.1.jpg", bbox_inches='tight')
plt.show()
# Out:
# /tmp/ipykernel_23297/3508281350.py:1: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   result = torch.load("results/1.1/masked_first/1.pt", map_location=torch.device('cpu'))
# tensor(18206)

# %%
result = torch.load("results/2/6/1.pt", map_location=torch.device('cpu'))
model = result["model"]
parameter = get_k_parameters(model).flatten()
print((parameter > 0.06).sum())
hist = torch.histogram(parameter[parameter > 0.06], bins=torch.tensor([0.0 + 0.005 * idx for idx in range(200)]))
plt.stairs(hist.hist.detach().numpy(), hist.bin_edges.detach().numpy(), fill=True)
plt.plot(parameter.max(), 60,'ro') 
plt.xlim([0.06, 1.03])
plt.ylim([0, 5_000])
plt.xlabel("Parameter Magnitude")
plt.ylabel("Frequency")
plt.savefig("Parameter_K_2.jpg", bbox_inches='tight')
plt.show()
# Out:
# /tmp/ipykernel_23297/4179328081.py:1: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   result = torch.load("results/2/masked_first/1.pt", map_location=torch.device('cpu'))
# tensor(27224)

# %%
result = torch.load("results/1.1/6/1.pt", map_location=torch.device('cpu'))
model = result["model"]
parameter = get_q_parameters(model).flatten()
print((parameter > 0.06).sum())
hist = torch.histogram(parameter[parameter > 0.06], bins=torch.tensor([0.06 + 0.005 * idx for idx in range(200)]))
plt.stairs(hist.hist.detach().numpy(), hist.bin_edges.detach().numpy(), fill=True)
plt.plot(parameter.max(), 60,'ro') 
plt.xlim([0.06, 0.5])
plt.ylim([0, 5_000])
plt.xlabel("Parameter Magnitude")
plt.ylabel("Frequency")
plt.savefig("Parameter_Q_1.1.jpg", bbox_inches='tight')
plt.show()
# Out:
# /tmp/ipykernel_23297/2096153087.py:1: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   result = torch.load("results/1.1/masked_first/1.pt", map_location=torch.device('cpu'))
# tensor(13964)

# %%
result = torch.load("results/2/6/1.pt", map_location=torch.device('cpu'))
model = result["model"]
parameter = get_q_parameters(model).flatten()
print((parameter > 0.06).sum())
hist = torch.histogram(parameter, bins=torch.tensor([0.06 + 0.005 * idx for idx in range(200)]))
plt.stairs(hist.hist.detach().numpy(), hist.bin_edges.detach().numpy(), fill=True)
plt.plot(parameter.max(), 60,'ro') 
plt.xlim([0.06, 0.5])
plt.ylim([0, 5_000])
plt.xlabel("Parameter Magnitude")
plt.ylabel("Frequency")
plt.savefig("Parameter_Q_2.jpg", bbox_inches='tight')
plt.show()
# Out:
# /tmp/ipykernel_23297/538841435.py:1: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   result = torch.load("results/2/masked_first/1.pt", map_location=torch.device('cpu'))
# tensor(14654)

# %%
result = torch.load("results/1.1/6/1.pt", map_location=torch.device('cpu'))
model = result["model"]
parameter = get_v_parameters(model).flatten()
print((parameter > 0.06).sum())
hist = torch.histogram(parameter[parameter > 0.06], bins=torch.tensor([0.06 + 0.005 * idx for idx in range(200)]))
plt.stairs(hist.hist.detach().numpy(), hist.bin_edges.detach().numpy(), fill=True)
plt.plot(parameter.max(), 40,'ro') 
plt.xlim([0.06, 1.2])
plt.ylim([0, 3_000])
plt.xlabel("Parameter Magnitude")
plt.ylabel("Frequency")
plt.savefig("Parameter_V_1.1.jpg", bbox_inches='tight')
plt.show()
# Out:
# /tmp/ipykernel_23297/1825558164.py:1: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   result = torch.load("results/1.1/masked_first/1.pt", map_location=torch.device('cpu'))
# tensor(7643)

# %%
result = torch.load("results/2/6/1.pt", map_location=torch.device('cpu'))
model = result["model"]
parameter = get_v_parameters(model).flatten()
print((parameter > 0.06).sum())
hist = torch.histogram(parameter, bins=torch.tensor([0.06 + 0.005 * idx for idx in range(200)]))
plt.stairs(hist.hist.detach().numpy(), hist.bin_edges.detach().numpy(), fill=True)
plt.plot(parameter.max(), 40,'ro') 
plt.xlim([0.06, 1.2])
plt.ylim([0, 3_000])
plt.xlabel("Parameter Magnitude")
plt.ylabel("Frequency")
plt.savefig("Parameter_V_2.jpg", bbox_inches='tight')
plt.show()
# Out:
# /tmp/ipykernel_23297/1761621281.py:1: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   result = torch.load("results/2/masked_first/1.pt", map_location=torch.device('cpu'))
# tensor(10127)
